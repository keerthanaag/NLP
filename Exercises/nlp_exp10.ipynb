# %%
pip install --upgrade pip
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pip in c:\users\gkeer\appdata\roaming\python\python311\site-packages (25.2)
# Collecting pip
#   Downloading pip-25.3-py3-none-any.whl.metadata (4.7 kB)
# Downloading pip-25.3-py3-none-any.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----------- ---------------------------- 0.5/1.8 MB 8.5 MB/s eta 0:00:01
#    ----------- ---------------------------- 0.5/1.8 MB 8.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 1.6/1.8 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 2.6 MB/s  0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 25.2
#     Uninstalling pip-25.2:
#       Successfully uninstalled pip-25.2
# Successfully installed pip-25.3
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts pip.exe, pip3.11.exe and pip3.exe are installed in 'C:\Users\gkeer\AppData\Roaming\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
pip install sumy
# Out:
# Note: you may need to restart the kernel to use updated packages.Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: sumy in c:\users\gkeer\appdata\roaming\python\python311\site-packages (0.11.0)
# Requirement already satisfied: docopt<0.7,>=0.6.1 in c:\users\gkeer\appdata\roaming\python\python311\site-packages (from sumy) (0.6.2)
# Requirement already satisfied: breadability>=0.1.20 in c:\users\gkeer\appdata\roaming\python\python311\site-packages (from sumy) (0.1.20)
# Requirement already satisfied: requests>=2.7.0 in c:\programdata\anaconda3\lib\site-packages (from sumy) (2.31.0)
# Requirement already satisfied: pycountry>=18.2.23 in c:\users\gkeer\appdata\roaming\python\python311\site-packages (from sumy) (23.12.11)
# Requirement already satisfied: nltk>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from sumy) (3.8.1)
# Requirement already satisfied: chardet in c:\programdata\anaconda3\lib\site-packages (from breadability>=0.1.20->sumy) (4.0.0)
# Requirement already satisfied: lxml>=2.0 in c:\programdata\anaconda3\lib\site-packages (from breadability>=0.1.20->sumy) (4.9.3)
# Requirement already satisfied: click in c:\programdata\anaconda3\lib\site-packages (from nltk>=3.0.2->sumy) (8.0.4)
# Requirement already satisfied: joblib in c:\programdata\anaconda3\lib\site-packages (from nltk>=3.0.2->sumy) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\programdata\anaconda3\lib\site-packages (from nltk>=3.0.2->sumy) (2022.7.9)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\lib\site-packages (from nltk>=3.0.2->sumy) (4.65.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.7.0->sumy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.7.0->sumy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.7.0->sumy) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.7.0->sumy) (2023.7.22)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from click->nltk>=3.0.2->sumy) (0.4.6)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import spacy
from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer
from sumy.summarizers.lsa import LsaSummarizer

# %%
nlp = spacy.load("en_core_web_sm")

# %%
def extract_text_from_file(file_path):
    with open(file_path, "r", encoding="utf-8") as file:
        text = file.read()
    return text

# %%
def generate_summary(text, num_sentences=2):
    # Preprocess text using spaCy
    doc = nlp(text)
    sentences = [sent.text for sent in doc.sents]

    # Join the sentences into a single string
    text = " ".join(sentences)

    # Use sumy to summarize the text
    parser = PlaintextParser.from_string(text, Tokenizer("english"))
    summarizer = LsaSummarizer()
    summary = summarizer(parser.document, num_sentences)

    # Convert summary sentences back to string
    summary_text = " ".join([str(sentence) for sentence in summary])
    return summary_text

# %%
file_path = "Example.txt"

# %%
document_text = extract_text_from_file(file_path)

# Generate summary
summary = generate_summary(document_text)

# Print the summary
print(summary)
# Out:
# 12/20/2023, 10:15 - John: Hey guys, how's it going? Let's plan a movie night then.
